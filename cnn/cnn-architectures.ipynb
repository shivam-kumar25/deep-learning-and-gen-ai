# %% [markdown]
# # CNN Architectures
# // Workflow
#
#
#
#
# <img src="image\Screenshot 2026-03-15 005826.png" alt="Screenshot 2026-03-15 005826.png" width="400"   >
#
# <img src="image\Screenshot 2026-03-15 010057.png" alt="Screenshot 2026-03-15 010057.png" width="400"   >
#
# <img src="image\Screenshot 2026-03-15 010137.png" alt="Screenshot 2026-03-15 010137.png" width="400"   >
#
# <img src="image\Screenshot 2026-03-15 010322.png" alt="Screenshot 2026-03-15 010322.png" width="400"   >
#
# <img src="image\Screenshot 2026-03-15 010436.png" alt="Screenshot 2026-03-15 010436.png" width="400"   >
#
# <img src="image\Screenshot 2026-03-15 010540.png" alt="Screenshot 2026-03-15 010540.png" width="400"   >

# %% [markdown]
# ## Famous CNN Architectures
# // State-of-the-art CNN architectures have evolved over time, each introducing new innovations to improve performance on various tasks. Here are some of the most famous CNN architectures
#
#
# <img src="image\Screenshot 2026-03-15 012926.png" alt="Screenshot 2026-03-15 012926.png" width="400"   >

# %% [markdown]
# ### AlexNet (2012)
#
#
# <img src="image\Screenshot 2026-03-15 013053.png" alt="Screenshot 2026-03-15 013053.png" width="400"   >
#
# <img src="image\Screenshot 2026-03-15 013213.png" alt="Screenshot 2026-03-15 013213.png" width="400"   >

# %% [markdown]
# ### VGGNet (2014)
#
# <img src="image\Screenshot 2026-03-15 013318.png" alt="Screenshot 2026-03-15 013318.png" width="400"   >

# %% [markdown]
# ### ResNet (2015)
#
# <img src="image\Screenshot 2026-03-15 013533.png" alt="Screenshot 2026-03-15 013533.png" width="400"   >
#
# <img src="image\Screenshot 2026-03-15 013603.png" alt="Screenshot 2026-03-15 013603.png" width="400"   >
#
# <img src="image\Screenshot 2026-03-15 013728.png" alt="Screenshot 2026-03-15 013728.png" width="400"   >

# %% [markdown]
# ### GoogLeNet (2014)
#
# <img src="image\Screenshot 2026-03-15 013848.png" alt="Screenshot 2026-03-15 013848.png" width="400"   >

# %% [markdown]
# <img src="image\Screenshot 2026-03-15 013948.png" alt="Screenshot 2026-03-15 013948.png" width="400"   >
#
#
#
# <img src="image\Screenshot 2026-03-15 014014.png" alt="Screenshot 2026-03-15 014014.png" width="400"   >
